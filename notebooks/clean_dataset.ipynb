# %%
import pandas as pd

df = pd.read_csv("../data/MachineLearningRating_v3.txt", sep="|")

df_clean = df.dropna()

df_clean.to_csv("../data/MachineLearningRating_v3_clean.csv", index=False)
# Out:
# C:\Users\redea\AppData\Local\Temp\ipykernel_18052\1835697444.py:3: DtypeWarning: Columns (0: CapitalOutstanding, 1: CrossBorder) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/MachineLearningRating_v3.txt", sep="|")
